# %%
# %matplotlib inline

import cv2 # The OpenCV library; install using `pip install opencv-contrib-python`
import numpy as np # Helpful when working with arrays; install using `pip install numpy`
from matplotlib import pyplot as plot # Good for graphing; install using `pip install matplotlib`
from matplotlib import image as image
import easygui # An easy-to-use file-picker; pip install easygui

# %% [markdown]
# ## Display video

# %%
# Video capture from a file:
Video = cv2.VideoCapture("Zorro.mp4")
(check, I) = Video.read()

while check:
    cv2.imshow("image", I)
    
    # This delays for 1ms while waiting for a key to be pressed
    key = cv2.waitKey(1)

    # if the 'q' keqy is pressed, quit:
    if key == ord("q"):
         break

    # Next Frame:
    (check, I) = Video.read()

Video.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Display a specific frame for 10 seconds

# %%
# Video capture from a file:
frame_no = 24
Video = cv2.VideoCapture("Zorro.mp4")
Video.set(1,frame_no); # Where frame_no is the frame you want
(check, I) = Video.read()
cv2.imshow("image", I)

# This delays for 1ms while waiting for a key to be pressed
key = cv2.waitKey(10000)

Video.release()
cv2.destroyAllWindows()

# %%
I = cv2.imread('water.jpg')

# %%
YUV = cv2.cvtColor(I, cv2.COLOR_BGR2YUV)
print("image")
print(YUV)
print("row")
print(YUV[0,:])
print("column")
print(YUV[:,0])
print("Y")
print(YUV[0][0][0])
# Out:
# image
# [[[123 174  28]
#   [126 173  31]
#   [131 172  34]
#   ...
#   [128 171  49]
#   [135 172  49]
#   [137 172  49]]
#
#  [[121 175  31]
#   [124 174  32]
#   [130 173  36]
#   ...
#   [128 172  49]
#   [133 172  49]
#   [134 172  49]]
#
#  [[119 176  34]
#   [123 176  36]
#   [128 175  39]
#   ...
#   [127 172  51]
#   [128 172  51]
#   [127 172  51]]
#
#  ...
#
#  [[ 91 180  57]
#   [ 91 180  57]
#   [ 91 180  57]
#   ...
#   [ 79 180  63]
#   [ 79 180  61]
#   [ 80 180  61]]
#
#  [[ 91 180  55]
#   [ 91 180  55]
#   [ 91 180  55]
#   ...
#   [ 79 180  61]
#   [ 80 180  61]
#   [ 80 180  61]]
#
#  [[ 93 180  55]
#   [ 93 180  55]
#   [ 93 180  55]
#   ...
#   [ 80 180  61]
#   [ 81 180  61]
#   [ 82 180  61]]]
# row
# [[123 174  28]
#  [126 173  31]
#  [131 172  34]
#  ...
#  [128 171  49]
#  [135 172  49]
#  [137 172  49]]
# column
# [[123 174  28]
#  [121 175  31]
#  [119 176  34]
#  ...
#  [ 91 180  57]
#  [ 91 180  55]
#  [ 93 180  55]]
# Y
# 123

# %% [markdown]
# ## Extract Y

# %%
y = YUV[:,:,0]
print(y)
# Out:
# [[123 126 131 ... 128 135 137]
#  [121 124 130 ... 128 133 134]
#  [119 123 128 ... 127 128 127]
#  ...
#  [ 91  91  91 ...  79  79  80]
#  [ 91  91  91 ...  79  80  80]
#  [ 93  93  93 ...  80  81  82]]

# %%
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
plot.imshow(I)

# %%
G = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow("Luminance", y)
cv2.imshow("Gray", G)
key = cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
fig, axs = plot.subplots(1, 2)
axs[0].set_title('Luminance')
axs[1].set_title('Intensity')
axs[0].imshow(y, cmap='gray')
axs[1].imshow(G, cmap='gray')
